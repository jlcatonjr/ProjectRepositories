# %%
import os
import pandas as pd
import datetime
state_dict = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ',
    'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 
    'Connecticut': 'CT', 'District of Columbia':"DC", 'Delaware': 'DE', 'Florida': 'FL', 
    'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL',
    'Indiana': 'IN', 'Iowa': 'IA','Kansas': 'KS', 'Kentucky': 'KY',
    'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA',
    'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
    'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
    'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI',
    'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX',
    'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA',
    'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY', "United States Total": "US"}

# %%
dfs_dct = {}
ab_keys = {"a": "United States Total", "b": "Missouri"}
for year in range(2009,2022):
    dfs_dct[year] = {}        
    stryear = str(year)
    filetype = ".xls"
    if year >= 2012:
        filetype = ".xlsx"
    for ab in ["a", "b"]:
        filename = f"StateGovFinances{stryear}{ab}{filetype}"
        try:
            df = pd.read_excel(filename)#dropna(axis = 0, how = "any")
        except:
            break
        index = [key for key in df if "Table" in key]
        df = df.set_index(index).iloc[5:]
        row = 0
        print(year)
        while ab_keys[ab] not in df.iloc[row].values:
            row +=1
        df.iloc[row] = df.iloc[row].fillna(method='ffill')
        df.iloc[row + 1] = df.iloc[row + 1].str.strip() + " " + df.iloc[row +2].str.replace("1", "").str.strip()+ " " + df.iloc[row +3].str.replace("1", "").str.strip()
        index = list(df.index)
        index[row+1] = "Variable"
        # df.set_index(index, inplace = True)
        # df.set_index(list(df.keys())[row, row + 1]) 
        # df.columns = df.iloc[[row, row + 1]].T

        # df = df.iloc[row + 6:].dropna(how = "all")
        df = df.iloc[row:].dropna(how = "all")

        df.index = [str(ix).strip().replace("1", "").upper() for ix in df.index]
        df_index_count = df.index.to_series().groupby(df.index).cumcount().add(1).astype(str)
        df.index = df_index_count + df_index_count.index
        tdf = df.T
        cols = list(tdf.iloc[1:].columns)
        cols[0] = "State"
        cols[1] = "Format"
        tdf.columns = cols
        tdf = tdf.iloc[1:]
        df = tdf    
        df["State"] = df["State"].apply(lambda x: state_dict[x])     
        df["Year"] = datetime.datetime(year,1,1)
        df.set_index(["State", "Year", "Format"], inplace = True)
        keys = list(df.keys())[4:]
        
        dfs_dct[year][ab] = df[keys]#reset_index().set_index(["Year", "index"])#.T
for year, ab_dct in dfs_dct.items():
    if "b" in ab_dct.keys():
        # dfs_dct[year] = pd.merge(ab_dct["a"], ab_dct["b"], how = "outer", left_index = True, right_index = True)
        dfs_dct[year] = pd.concat([ab_dct["a"], ab_dct["b"]])        
    else:
        dfs_dct[year] = ab_dct["a"]
    dfs_dct[year] = dfs_dct[year]
    # dfs_dct[year].set_index("index", inplace = True)
    # dfs_dct[year].index.name = "Description"
# Out:
# 2009
# 2009
# 2010
# 2010
# 2011
# 2011
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2012
# 2012
# 2013
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2013
# 2014
# 2014
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2015
# 2015
# 2016
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2016
# 2017
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2018
# 2019
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# 2020
# 2021
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')
# /tmp/ipykernel_6654/3297417039.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[row] = df.iloc[row].fillna(method='ffill')

# %%
# dfs_dct = {}
# ab_keys = {"a": "United States Total", "b": "Missouri"}
# for year in range(2009,2022):
#     dfs_dct[year] = {}        
#     stryear = str(year)
#     filetype = ".xls"
#     if year >= 2012:
#         filetype = ".xlsx"
#     print(year)
#     for ab in ["a", "b"]:
#         filename = f"StateGovFinances{stryear}{ab}{filetype}"
#         try:
#             df = pd.read_excel(filename)#dropna(axis = 0, how = "any")
#         except:
#             print(f"Could not read {filename}")
#             break
#         index = [key for key in df if "Table" in key]
#         df = df.set_index(index).iloc[5:]
#         row = 0
#         while ab_keys[ab] not in df.iloc[row].values:
#             row +=1
#         df.iloc[row] = df.iloc[row].fillna(method='ffill')
#         df.iloc[row] = df.iloc[row].str.strip() + " " +  df.iloc[row + 1].str.strip() + " " + df.iloc[row +2].str.replace("1", "").str.strip()+ " " + df.iloc[row +3].str.replace("1", "").str.strip()
#         df.columns = df.iloc[row].str.title()
#         df = df.iloc[row + 6:].dropna(how = "all")
#         df.index = [ix.strip().replace("1", "").upper() for ix in df.index]
#         df_index_count = df.index.to_series().groupby(df.index).cumcount().add(1).astype(str)
#         df.index = df_index_count + df_index_count.index
#         df["Year"] = datetime.datetime(year,1,1)
#         dfs_dct[year][ab] = df.copy().reset_index().set_index(["Year", "index"]).T   
# dfs_dct[year]
# # for key, dct in dfs_dct.items():
# #     ab = list(dct.keys())
# #     if "a" in ab and "b" in ab:
# #         dfs_dct[key] = pd.merge(dct["a"], dct["b"], how = "outer", left_index = True, right_index = True)
# #     else:
# #         dfs_dct[key] = dct["a"]

# %%
stack_dfs = pd.concat([dfs_dct[year] for year in range(2009, 2022)])#.reset_index().set_index(["index", "Year"])
print(stack_dfs)
# Out:
#                                                  1GENERAL REVENUE  \
# State Year       Format
# US    2009-01-01 State & local government CV                 0.08
#                  State government amount               1493989614
#                  Local government amount               1426542702
#                  Local government CV                         0.15
# AL    2009-01-01 State & local government amount         32547640
# ...                                                           ...
# WY    2021-01-01 State & local government amount          9844705
#                  State & local government CV                 0.19
#                  State government amount                  6375373
#                  Local government amount                  5318614
#                  Local government CV                         0.41
#
#                                                  1INTERGOVERNMENTAL REVENUE  \
# State Year       Format
# US    2009-01-01 State & local government CV                           0.11
#                  State government amount                          494782446
#                  Local government amount                          534027275
#                  Local government CV                                   0.18
# AL    2009-01-01 State & local government amount                    8538474
# ...                                                                     ...
# WY    2021-01-01 State & local government amount                    3433945
#                  State & local government CV                           0.36
#                  State government amount                            3103070
#                  Local government amount                            2180157
#                  Local government CV                                   0.78
#
#                                                  1FROM FEDERAL GOVERNMENT  \
# State Year       Format
# US    2009-01-01 State & local government CV                         0.11
#                  State government amount                        475661252
#                  Local government amount                         62288130
#                  Local government CV                                 0.94
# AL    2009-01-01 State & local government amount                  8538474
# ...                                                                   ...
# WY    2021-01-01 State & local government amount                  3433945
#                  State & local government CV                         0.36
#                  State government amount                          3089280
#                  Local government amount                           344665
#                  Local government CV                                 3.55
#
#                                                  1FROM STATE GOVERNMENT  \
# State Year       Format
# US    2009-01-01 State & local government CV                          0
#                  State government amount                              0
#                  Local government CV                             0.12
# AL    2009-01-01 State & local government amount             23454844
# ...                                                               ...
# WY    2021-01-01 State & local government amount             11098978
#                  State & local government CV                        0
#                  State government amount                     11098978
#                  Local government amount                            0
#                  Local government CV                                0
#
#                                                  3WORKERS' COMPENSATION  \
# State Year       Format
# US    2009-01-01 State & local government CV                          0
#                  State government amount                       87489015
#                  Local government amount                              0
#                  Local government CV                                  0
# AL    2009-01-01 State & local government amount                      0
# ...                                                                 ...
# WY    2021-01-01 State & local government amount                2402182
#                  State & local government CV                          0
#                  State government amount                        2402182
#                  Local government amount                              0
#                  Local government CV                                  0
#
#                                                  1MISCELLANEOUS  \
# State Year       Format
# US    2009-01-01 State & local government CV                  0
#                  State government amount                5735626
#                  Local government amount                      0
#                  Local government CV                          0
# AL    2009-01-01 State & local government amount              0
# ...                                                         ...
# WY    2021-01-01 State & local government amount              0
#                  State & local government CV                  0
#                  State government amount                      0
#                  Local government amount                      0
#                  Local government CV                          0
#
#                                                  1OTHER THAN INSURANCE TRUST FUNDS  \
# State Year       Format
# US    2009-01-01 State & local government CV                                  0.19
#                  State government amount                                1061582901
#                  Local government amount                                1055959766
#                  Local government CV                                          0.39
# AL    2009-01-01 State & local government amount                          21157699
# ...                                                                            ...
# WY    2021-01-01 State & local government amount                          31043052
#                  State & local government CV                                  0.45
#                  State government amount                                  25724647
#                  Local government amount                                   5318405
#                  Local government CV                                           2.6
#
#                                                  1OFFSETS TO DEBT 1BOND FUNDS  \
# State Year       Format
# US    2009-01-01 State & local government CV                  0.2        0.43
#                  State government amount                491111560    51476538
#                  Local government amount                307364131   162284362
#                  Local government CV                         0.52        0.56
# AL    2009-01-01 State & local government amount          3768036     2887860
# ...                                                           ...         ...
# WY    2021-01-01 State & local government amount           947713      154361
#                  State & local government CV                 0.33        0.22
#                  State government amount                   835876      137227
#                  Local government amount                   111837       17134
#                  Local government CV                         2.81        1.95
#
#                                                      1OTHER  1REVENUE  \
# State Year       Format
# US    2009-01-01 State & local government CV           0.33       NaN
#                  State government amount          518994803       NaN
#                  Local government amount          586311273       NaN
#                  Local government CV                   0.63       NaN
# AL    2009-01-01 State & local government amount   14501803       NaN
# ...                                                     ...       ...
# WY    2021-01-01 State & local government amount   29940978  11886452
#                  State & local government CV           0.46      0.18
#                  State government amount           24751544   8179668
#                  Local government amount            5189434   5556067
#                  Local government CV                   2.67      0.44
#
#                                                  1EMPLOYMENT SECURITY ADMINISTRATION
# State Year       Format
# US    2009-01-01 State & local government CV                                     NaN
#                  State government amount                                         NaN
#                  Local government amount                                         NaN
#                  Local government CV                                             NaN
# AL    2009-01-01 State & local government amount                                 NaN
# ...                                                                              ...
# WY    2021-01-01 State & local government amount                               25051
#                  State & local government CV                                       0
#                  State government amount                                       25051
#                  Local government amount                                           0
#                  Local government CV                                               0
#
# [3270 rows x 140 columns]

# %%
before2009 = pd.read_csv("StateGovFinancesTo2008.csv", parse_dates=True)
before2009["Year4"] = pd.to_datetime(before2009["Year4"], format = "%Y")
before2009["State"] = before2009["Name"].str[:2]
before2009 = before2009.set_index(["State","Year4"]).sort_index()
names = ["Population (000)", "Personal Income ($mil)", "Total Revenue", "Total Rev-Own Sources",	"Total Taxes", "Property Tax (T01)", "Special Assessments (U01)", "Total IG Revenue", "Total Fed IG Revenue"]
before2009[names]
# Out:
#                   Population (000)  Personal Income ($mil)  Total Revenue  \
# State Year4
# AK    1957-01-01             231.0                     539          38652
#       1958-01-01             224.0                     559          46252
#       1959-01-01             224.0                     593          50024
#       1960-01-01             229.0                     701          74646
#       1961-01-01             238.0                     698          79609
# ...                            ...                     ...            ...
# WY    2004-01-01             503.0                   18239        4609487
#       2005-01-01             507.0                   18902        5296649
#       2006-01-01             513.0                   22912        5831362
#       2007-01-01             523.0                   24457        6091326
#       2008-01-01             533.0                   25892        6718235
#
#                   Total Rev-Own Sources  Total Taxes  Property Tax (T01)  \
# State Year4
# AK    1957-01-01                  27789        20974                   2
#       1958-01-01                  31306        23263                   1
#       1959-01-01                  31687        24045                  32
#       1960-01-01                  41305        27110                 542
#       1961-01-01                  48585        31571                 219
# ...                                 ...          ...                 ...
# WY    2004-01-01                3175375      1504777              139809
#       2005-01-01                3361770      1739646              180821
#       2006-01-01                3822058      2122239              217907
#       2007-01-01                4144068      2025090              266498
#       2008-01-01                4553583      2404843              278812
#
#                   Special Assessments (U01)  Total IG Revenue  \
# State Year4
# AK    1957-01-01                          0             10863
#       1958-01-01                          0             14946
#       1959-01-01                          0             18337
#       1960-01-01                          0             33341
#       1961-01-01                          0             31024
# ...                                     ...               ...
# WY    2004-01-01                          0           1434112
#       2005-01-01                          0           1934879
#       2006-01-01                          0           2009304
#       2007-01-01                          0           1947258
#       2008-01-01                          0           2164652
#
#                   Total Fed IG Revenue
# State Year4
# AK    1957-01-01                 10713
#       1958-01-01                 14786
#       1959-01-01                 18191
#       1960-01-01                 33081
#       1961-01-01                 30974
# ...                                ...
# WY    2004-01-01               1369382
#       2005-01-01               1824032
#       2006-01-01               1957575
#       2007-01-01               1776003
#       2008-01-01               1997454
#
# [3259 rows x 9 columns]

# %%
before2009["Special Assessments (U01)"]
# Out:
# State  Year4
# AK     1957-01-01    0
#        1958-01-01    0
#        1959-01-01    0
#        1960-01-01    0
#        1961-01-01    0
#                     ..
# WY     2004-01-01    0
#        2005-01-01    0
#        2006-01-01    0
#        2007-01-01    0
#        2008-01-01    0
# Name: Special Assessments (U01), Length: 3259, dtype: int64

# %%
stack_dfs.to_csv("StateGovFinances2009to2021.csv")

# %%
stack_dfs.index.get_level_values("Format").unique()
# Out:
# Index(['State & local government CV', 'State government amount',
#        'Local government amount', 'Local government CV',
#        'State & local government amount'],
#       dtype='object', name='Format')

# %%
stack_dfs[stack_dfs.index.get_level_values("Format") == "State & local government amount"]
# Out:
#                                                  1GENERAL REVENUE  \
# State Year       Format
# AL    2009-01-01 State & local government amount         32547640
# AK    2009-01-01 State & local government amount         14283410
# AZ    2009-01-01 State & local government amount         41184122
# AR    2009-01-01 State & local government amount         18964574
# CA    2009-01-01 State & local government amount        319737124
# AK    2009-01-01 State & local government amount    6529743   1199981
# AZ    2009-01-01 State & local government amount   20610710   7140762
# AR    2009-01-01 State & local government amount    9471918   1566872
# CA    2009-01-01 State & local government amount  171150903  54894861
# ...                                                     ...       ...
# VA    2021-01-01 State & local government amount   53564770  16566844
# WA    2021-01-01 State & local government amount   51574328  14711643
# WV    2021-01-01 State & local government amount    8386049   1921893
# WI    2021-01-01 State & local government amount   33548631  10485666
# WY    2021-01-01 State & local government amount    3015682   1251792
#
#                                                  1SALES AND GROSS RECEIPTS  \
# State Year       Format
# AL    2009-01-01 State & local government amount                   6356730
# AK    2009-01-01 State & local government amount                    697272
# AZ    2009-01-01 State & local government amount                   9481766
# AR    2009-01-01 State & local government amount                   4887205
# CA    2009-01-01 State & local government amount                  49791510
# ...                                                                    ...
# VA    2021-01-01 State & local government amount                  14784519
# WA    2021-01-01 State & local government amount                  31163082
# WV    2021-01-01 State & local government amount                   3125864
# WI    2021-01-01 State & local government amount                   9748094
# WY    2021-01-01 State & local government amount                   1049028
#
#                                                  1GENERAL SALES  ...  \
# State Year       Format                                          ...
# AL    2009-01-01 State & local government amount        3945636  ...
# AK    2009-01-01 State & local government amount         370640  ...
# AZ    2009-01-01 State & local government amount        7318393  ...
# AR    2009-01-01 State & local government amount        3730837  ...
# CA    2009-01-01 State & local government amount       37705575  ...
# ...                                                         ...  ...
# VA    2021-01-01 State & local government amount        8143608  ...
# WA    2021-01-01 State & local government amount       24431426  ...
# WV    2021-01-01 State & local government amount        1609537  ...
# WI    2021-01-01 State & local government amount        6857316  ...
# WY    2021-01-01 State & local government amount         827323  ...
#
#                                                  3UNEMPLOYMENT COMPENSATION  \
# State Year       Format
# AL    2009-01-01 State & local government amount                     112446
# AK    2009-01-01 State & local government amount                     324540
# AZ    2009-01-01 State & local government amount                     599156
# AR    2009-01-01 State & local government amount                     -60047
# CA    2009-01-01 State & local government amount                   -1708044
# ...                                                                     ...
# VA    2021-01-01 State & local government amount                     325679
# WA    2021-01-01 State & local government amount                    3725432
# WV    2021-01-01 State & local government amount                     -26668
# WI    2021-01-01 State & local government amount                    2058284
# WY    2021-01-01 State & local government amount                     651360
#
#                                                  3EMPLOYEE RETIREMENT  \
# State Year       Format
# AL    2009-01-01 State & local government amount             23454844
# AK    2009-01-01 State & local government amount              7579367
# AZ    2009-01-01 State & local government amount             26707631
# AR    2009-01-01 State & local government amount             14740895
# CA    2009-01-01 State & local government amount            431681861
# ...                                                               ...
# VA    2021-01-01 State & local government amount            121332853
# WA    2021-01-01 State & local government amount            143815672
# WV    2021-01-01 State & local government amount             21270352
# WI    2021-01-01 State & local government amount            153468102
# WY    2021-01-01 State & local government amount             11098978
#
#                                                  3WORKERS' COMPENSATION  \
# State Year       Format
# AL    2009-01-01 State & local government amount                      0
# AK    2009-01-01 State & local government amount                  17478
# AZ    2009-01-01 State & local government amount                3356026
# AR    2009-01-01 State & local government amount                 157555
# CA    2009-01-01 State & local government amount               20464049
# ...                                                                 ...
# VA    2021-01-01 State & local government amount                   3676
# WA    2021-01-01 State & local government amount               21318520
# WV    2021-01-01 State & local government amount                1452789
# WI    2021-01-01 State & local government amount                  34427
# WY    2021-01-01 State & local government amount                2402182
#
#                                                  1MISCELLANEOUS  \
# State Year       Format
# AL    2009-01-01 State & local government amount              0
# AK    2009-01-01 State & local government amount              0
# AZ    2009-01-01 State & local government amount              0
# AR    2009-01-01 State & local government amount              0
# CA    2009-01-01 State & local government amount        4901868
# ...                                                         ...
# VA    2021-01-01 State & local government amount              0
# WA    2021-01-01 State & local government amount              0
# WV    2021-01-01 State & local government amount              0
# WI    2021-01-01 State & local government amount              0
# WY    2021-01-01 State & local government amount              0
#
#                                                  1OTHER THAN INSURANCE TRUST FUNDS  \
# State Year       Format
# AL    2009-01-01 State & local government amount                          21157699
# AK    2009-01-01 State & local government amount                          53078533
# AZ    2009-01-01 State & local government amount                          33527002
# AR    2009-01-01 State & local government amount                          13378024
# CA    2009-01-01 State & local government amount                         281649814
# ...                                                                            ...
# VA    2021-01-01 State & local government amount                          86508254
# WA    2021-01-01 State & local government amount                          60840503
# WV    2021-01-01 State & local government amount                          11135320
# WI    2021-01-01 State & local government amount                          42105913
# WY    2021-01-01 State & local government amount                          31043052
#
#                                                  1OFFSETS TO DEBT 1BOND FUNDS  \
# State Year       Format
# AL    2009-01-01 State & local government amount          3768036     2887860
# AK    2009-01-01 State & local government amount          4175204      471966
# AZ    2009-01-01 State & local government amount         12553995     6028944
# AR    2009-01-01 State & local government amount          5334084     1148825
# CA    2009-01-01 State & local government amount         56235180    47457174
# ...                                                           ...         ...
# VA    2021-01-01 State & local government amount         19243856     6398347
# WA    2021-01-01 State & local government amount         10596552     6653871
# WV    2021-01-01 State & local government amount          1130623      609589
# WI    2021-01-01 State & local government amount         15172248     2945362
# WY    2021-01-01 State & local government amount           947713      154361
#
#                                                      1OTHER   1REVENUE  \
# State Year       Format
# AL    2009-01-01 State & local government amount   14501803        NaN
# AK    2009-01-01 State & local government amount   48431363        NaN
# AZ    2009-01-01 State & local government amount   14944063        NaN
# AR    2009-01-01 State & local government amount    6895115        NaN
# CA    2009-01-01 State & local government amount  177957460        NaN
# ...                                                     ...        ...
# VA    2021-01-01 State & local government amount   60866051  135480993
# WA    2021-01-01 State & local government amount   43590080  148243176
# WV    2021-01-01 State & local government amount    9395108   26944612
# WI    2021-01-01 State & local government amount   23988303   85839258
# WY    2021-01-01 State & local government amount   29940978   11886452
#
#                                                  1EMPLOYMENT SECURITY ADMINISTRATION
# State Year       Format
# AL    2009-01-01 State & local government amount                                 NaN
# AK    2009-01-01 State & local government amount                                 NaN
# AZ    2009-01-01 State & local government amount                                 NaN
# AR    2009-01-01 State & local government amount                                 NaN
# CA    2009-01-01 State & local government amount                                 NaN
# ...                                                                              ...
# VA    2021-01-01 State & local government amount                              147576
# WA    2021-01-01 State & local government amount                              294913
# WV    2021-01-01 State & local government amount                               32021
# WI    2021-01-01 State & local government amount                              170020
# WY    2021-01-01 State & local government amount                               25051
#
# [670 rows x 140 columns]
